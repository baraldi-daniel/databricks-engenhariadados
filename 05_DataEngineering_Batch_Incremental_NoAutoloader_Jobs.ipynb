# %% [markdown]
# ![./ImageLab.png](./Images/ImageLab.png "./ImageLab.png")

# %% [markdown]
# # Data Engineering with Lakeflow, Jobs, AutoLoader and more

# %% [markdown]
# ## Jobs Definition

# %%
from pyspark.sql import functions as F

# %% [markdown]
# Go to the Jobs & Pipelines tab and configure the Job as below

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.32.44.png](./Images/Screenshot 2026-01-08 at 17.32.44.png "Screenshot 2026-01-08 at 17.32.44.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.43.54.png](./Images/Screenshot 2026-01-08 at 17.43.54.png "Screenshot 2026-01-08 at 17.43.54.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.35.31.png](./Images/Screenshot 2026-01-08 at 17.35.31.png "Screenshot 2026-01-08 at 17.35.31.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.36.13.png](./Images/Screenshot 2026-01-08 at 17.36.13.png "Screenshot 2026-01-08 at 17.36.13.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.37.54.png](./Images/Screenshot 2026-01-08 at 17.37.54.png "Screenshot 2026-01-08 at 17.37.54.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 17.39.43.png](./Images/Screenshot 2026-01-08 at 17.39.43.png "Screenshot 2026-01-08 at 17.39.43.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 18.07.21.png](./Images/Screenshot 2026-01-08 at 18.07.21.png "Screenshot 2026-01-08 at 18.07.21.png")

# %% [markdown]
# Upload a new file and run the Job checking the table

# %% [markdown]
# ![Screenshot 2026-01-08 at 20.51.14.png](./Images/Screenshot 2026-01-08 at 20.51.14.png "Screenshot 2026-01-08 at 20.51.14.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 20.50.43.png](./Images/Screenshot 2026-01-08 at 20.50.43.png "Screenshot 2026-01-08 at 20.50.43.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 20.50.54.png](./Images/Screenshot 2026-01-08 at 20.50.54.png "Screenshot 2026-01-08 at 20.50.54.png")
