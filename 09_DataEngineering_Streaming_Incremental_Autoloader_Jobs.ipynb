# %% [markdown]
# ![./ImageLab.png](./Images/ImageLab.png "./ImageLab.png")

# %% [markdown]
# # Data Engineering with Lakeflow, Jobs, AutoLoader and more

# %% [markdown]
# ## Jobs Definition

# %%
from pyspark.sql import functions as F

# %% [markdown]
# Go to the Jobs & Pipelines tab and configure the Job as below

# %% [markdown]
# ![Screenshot 2026-01-08 at 22.10.17.png](./Images/Screenshot 2026-01-08 at 22.10.17.png "Screenshot 2026-01-08 at 22.10.17.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 22.09.57.png](./Images/Screenshot 2026-01-08 at 22.09.57.png "Screenshot 2026-01-08 at 22.09.57.png")

# %% [markdown]
# ![Screenshot 2026-01-08 at 22.11.28.png](./Images/Screenshot 2026-01-08 at 22.11.28.png "Screenshot 2026-01-08 at 22.11.28.png")

# %% [markdown]
# Upload a new file and run the Job checking the table

# %% [markdown]
# ![Screenshot 2026-01-09 at 01.08.01.png](./Images/Screenshot 2026-01-09 at 01.08.01.png "Screenshot 2026-01-09 at 01.08.01.png")

# %% [markdown]
# ![Screenshot 2026-01-09 at 01.07.52.png](./Images/Screenshot 2026-01-09 at 01.07.52.png "Screenshot 2026-01-09 at 01.07.52.png")
